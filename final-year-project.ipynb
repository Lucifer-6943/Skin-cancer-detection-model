# %%
"""
Skin cancer lesion classification using the HAM10000 dataset

Dataset link:
https://www.kaggle.com/kmader/skin-cancer-mnist-ham10000
Data description: 
https://arxiv.org/ftp/arxiv/papers/1803/1803.10417.pdf

The 7 classes of skin cancer lesions included in this dataset are:
Melanocytic nevi (nv)
Melanoma (mel)
Benign keratosis-like lesions (bkl)
Basal cell carcinoma (bcc) 
Actinic keratoses (akiec)
Vascular lesions (vas)
Dermatofibroma (df)
"""


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

np.random.seed(42)
from sklearn.metrics import confusion_matrix

import keras
from keras.utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.preprocessing import LabelEncoder

skin_df = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
print(skin_df)
# Out:
# 2024-03-04 02:05:36.164976: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 02:05:36.165081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 02:05:36.304846: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
SIZE=32

# label encoding to numeric values from text
le = LabelEncoder()
le.fit(skin_df['dx'])
LabelEncoder()
print(list(le.classes_))
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
skin_df['label'] = le.transform(skin_df["dx"]) 
print(skin_df.sample(10))
# Out:
#         lesion_id      image_id   dx    dx_type   age     sex  \
# 1617  HAM_0007180  ISIC_0033272  mel      histo  65.0    male
# 8128  HAM_0007195  ISIC_0031923   nv      histo  40.0  female
# 2168  HAM_0001835  ISIC_0026652  mel      histo  65.0    male
# 1090  HAM_0000465  ISIC_0030583  bkl  consensus  35.0  female
# 7754  HAM_0001720  ISIC_0034010   nv      histo  45.0    male
# 8071  HAM_0006333  ISIC_0024424   nv      histo  35.0    male
# 7423  HAM_0004548  ISIC_0032832   nv      histo  45.0  female
# 8984  HAM_0006526  ISIC_0026671   nv      histo  55.0    male
# 2310  HAM_0003102  ISIC_0032389  mel      histo  65.0    male
# 7256  HAM_0004260  ISIC_0025525   nv      histo  65.0    male
#
#          localization  label
# 1617             face      4
# 8128  lower extremity      5
# 2168             back      4
# 1090            trunk      2
# 7754          abdomen      5
# 8071            trunk      5
# 7423  upper extremity      5
# 8984  lower extremity      5
# 2310             face      4
# 7256             back      5

# %%
# Data distribution visualization
fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(221)
skin_df['dx'].value_counts().plot(kind='bar', ax=ax1)
ax1.set_ylabel('Count')
ax1.set_title('Cell Type');

ax2 = fig.add_subplot(222)
skin_df['sex'].value_counts().plot(kind='bar', ax=ax2)
ax2.set_ylabel('Count', size=15)
ax2.set_title('Sex');

ax3 = fig.add_subplot(223)
skin_df['localization'].value_counts().plot(kind='bar')
ax3.set_ylabel('Count',size=12)
ax3.set_title('Localization')

ax4 = fig.add_subplot(224)
sample_age = skin_df[pd.notnull(skin_df['age'])]
sns.distplot(sample_age['age'], fit=stats.norm, color='red');
ax4.set_title('Age')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_34/3885637716.py:21: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_age['age'], fit=stats.norm, color='red');
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Distribution of data into various classes 
from sklearn.utils import resample
print(skin_df['label'].value_counts())
# Out:
# label
# 5    6705
# 4    1113
# 2    1099
# 1     514
# 0     327
# 6     142
# 3     115
# Name: count, dtype: int64

# %%
#Balance data.
# Many ways to balance data... you can also try assigning weights during model.fit
#Separate each classes, resample, and combine back into single dataframe

df_0 = skin_df[skin_df['label'] == 0]
df_1 = skin_df[skin_df['label'] == 1]
df_2 = skin_df[skin_df['label'] == 2]
df_3 = skin_df[skin_df['label'] == 3]
df_4 = skin_df[skin_df['label'] == 4]
df_5 = skin_df[skin_df['label'] == 5]
df_6 = skin_df[skin_df['label'] == 6]

# %%
n_samples=6500 
df_0_balanced = resample(df_0, replace=True, n_samples=n_samples, random_state=42) 
df_1_balanced = resample(df_1, replace=True, n_samples=n_samples, random_state=42) 
df_2_balanced = resample(df_2, replace=True, n_samples=n_samples, random_state=42)
df_3_balanced = resample(df_3, replace=True, n_samples=n_samples, random_state=42)
df_4_balanced = resample(df_4, replace=True, n_samples=n_samples, random_state=42)
df_5_balanced = resample(df_5, replace=True, n_samples=n_samples, random_state=42)
df_6_balanced = resample(df_6, replace=True, n_samples=n_samples, random_state=42)

# %%
#Combined back to a single dataframe
skin_df_balanced = pd.concat([df_0_balanced, df_1_balanced, 
                              df_2_balanced, df_3_balanced, 
                              df_4_balanced, df_5_balanced, df_6_balanced])

# %%
#Check the distribution. All classes should be balanced now.
print(skin_df_balanced['label'].value_counts())
# Out:
# label
# 0    6500
# 1    6500
# 2    6500
# 3    6500
# 4    6500
# 5    6500
# 6    6500
# Name: count, dtype: int64

# %%
#Now time to read images based on image ID from the CSV file
#This is the safest way to read images as it ensures the right image is read for the right ID
image_path = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join('/kaggle/input/skin-cancer-mnist-ham10000', '*', '*.jpg'))}

# %%
#Define the path and add as a new column
skin_df_balanced['path'] = skin_df['image_id'].map(image_path.get)
#Use the path to read images.
skin_df_balanced['image'] = skin_df_balanced['path'].map(lambda x: np.asarray(Image.open(x).resize((SIZE,SIZE))))

# %%
n_samples = 5  # number of samples for plotting
# Plotting
fig, m_axs = plt.subplots(7, n_samples, figsize = (4*n_samples, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs, 
                                         skin_df_balanced.sort_values(['dx']).groupby('dx')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=1234).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')

# %%
#Convert dataframe column of images into numpy array
X = np.asarray(skin_df_balanced['image'].tolist())
X = X/255.  # Scale values to 0-1. You can also used standardscaler or other scaling methods.
Y=skin_df_balanced['label']  #Assign label values to Y
Y_cat = to_categorical(Y, num_classes=7) #Convert to categorical as this is a multiclass classification problem
#Split to training and testing
x_train, x_test, y_train, y_test = train_test_split(X, Y_cat, test_size=0.25, random_state=42)

# %%
#Define the model.
#I've used autokeras to find out the best model for this problem.
#You can also load pretrained networks such as mobilenet or VGG16

num_classes = 7

model = Sequential()
model.add(Conv2D(256, (3, 3), activation="relu", input_shape=(SIZE, SIZE, 3)))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3),activation='relu'))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3),activation='relu'))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))
model.add(Flatten())

model.add(Dense(32))
model.add(Dense(7, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['acc'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 256)       7168
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 256)       0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 256)       0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 128)       295040
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          73792
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 64)          0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 32)                8224
#
#  dense_1 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 384455 (1.47 MB)
# Trainable params: 384455 (1.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train
#You can also use generator to use augmentation during training.

batch_size = 16 
epochs = 200

history = model.fit(
    x_train, y_train,
    epochs=epochs,
    batch_size = batch_size,
    validation_data=(x_test, y_test),
    verbose=2)

score = model.evaluate(x_test, y_test)
print('Test accuracy:', score[1])
# Out:
# Epoch 1/200
# 2024-03-04 02:13:10.683504: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709518393.055225     103 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2133/2133 - 16s - loss: 1.4472 - acc: 0.4139 - val_loss: 1.2051 - val_acc: 0.5408 - 16s/epoch - 8ms/step
# Epoch 2/200
# 2133/2133 - 11s - loss: 1.1632 - acc: 0.5512 - val_loss: 1.1454 - val_acc: 0.5379 - 11s/epoch - 5ms/step
# Epoch 3/200
# 2133/2133 - 11s - loss: 1.0522 - acc: 0.6072 - val_loss: 0.8491 - val_acc: 0.6917 - 11s/epoch - 5ms/step
# Epoch 4/200
# 2133/2133 - 11s - loss: 0.9448 - acc: 0.6416 - val_loss: 0.7609 - val_acc: 0.7284 - 11s/epoch - 5ms/step
# Epoch 5/200
# 2133/2133 - 11s - loss: 0.9002 - acc: 0.6676 - val_loss: 0.8130 - val_acc: 0.6826 - 11s/epoch - 5ms/step
# Epoch 6/200
# 2133/2133 - 11s - loss: 0.8491 - acc: 0.6826 - val_loss: 0.6515 - val_acc: 0.7733 - 11s/epoch - 5ms/step
# Epoch 7/200
# 2133/2133 - 11s - loss: 0.8357 - acc: 0.6998 - val_loss: 0.6119 - val_acc: 0.7826 - 11s/epoch - 5ms/step
# Epoch 8/200
# 2133/2133 - 10s - loss: 0.8165 - acc: 0.7083 - val_loss: 0.7159 - val_acc: 0.7290 - 10s/epoch - 5ms/step
# Epoch 9/200
# 2133/2133 - 11s - loss: 0.8381 - acc: 0.7135 - val_loss: 0.6347 - val_acc: 0.7715 - 11s/epoch - 5ms/step
# Epoch 10/200
# 2133/2133 - 11s - loss: 0.8217 - acc: 0.7239 - val_loss: 0.5714 - val_acc: 0.7822 - 11s/epoch - 5ms/step
# Epoch 11/200
# 2133/2133 - 10s - loss: 0.7582 - acc: 0.7332 - val_loss: 0.5116 - val_acc: 0.8164 - 10s/epoch - 5ms/step
# Epoch 12/200
# 2133/2133 - 11s - loss: 0.7205 - acc: 0.7393 - val_loss: 0.5412 - val_acc: 0.8067 - 11s/epoch - 5ms/step
# Epoch 13/200
# 2133/2133 - 11s - loss: 0.7290 - acc: 0.7460 - val_loss: 0.5266 - val_acc: 0.8193 - 11s/epoch - 5ms/step
# Epoch 14/200
# 2133/2133 - 10s - loss: 0.8006 - acc: 0.7509 - val_loss: 0.6481 - val_acc: 0.7567 - 10s/epoch - 5ms/step
# Epoch 15/200
# 2133/2133 - 11s - loss: 0.6887 - acc: 0.7484 - val_loss: 0.4679 - val_acc: 0.8392 - 11s/epoch - 5ms/step
# Epoch 16/200
# 2133/2133 - 10s - loss: 0.6698 - acc: 0.7673 - val_loss: 0.4674 - val_acc: 0.8384 - 10s/epoch - 5ms/step
# Epoch 17/200
# 2133/2133 - 10s - loss: 0.6674 - acc: 0.7639 - val_loss: 0.4350 - val_acc: 0.8524 - 10s/epoch - 5ms/step
# Epoch 18/200
# 2133/2133 - 11s - loss: 0.6376 - acc: 0.7697 - val_loss: 0.4344 - val_acc: 0.8538 - 11s/epoch - 5ms/step
# Epoch 19/200
# 2133/2133 - 10s - loss: 0.6820 - acc: 0.7743 - val_loss: 0.4542 - val_acc: 0.8442 - 10s/epoch - 5ms/step
# Epoch 20/200
# 2133/2133 - 11s - loss: 0.6110 - acc: 0.7782 - val_loss: 0.4400 - val_acc: 0.8545 - 11s/epoch - 5ms/step
# Epoch 21/200
# 2133/2133 - 11s - loss: 0.6471 - acc: 0.7799 - val_loss: 0.4092 - val_acc: 0.8636 - 11s/epoch - 5ms/step
# Epoch 22/200
# 2133/2133 - 10s - loss: 0.5801 - acc: 0.7825 - val_loss: 0.4014 - val_acc: 0.8592 - 10s/epoch - 5ms/step
# Epoch 23/200
# 2133/2133 - 10s - loss: 0.5987 - acc: 0.7899 - val_loss: 0.3689 - val_acc: 0.8735 - 10s/epoch - 5ms/step
# Epoch 24/200
# 2133/2133 - 11s - loss: 0.5810 - acc: 0.7937 - val_loss: 0.3521 - val_acc: 0.8787 - 11s/epoch - 5ms/step
# Epoch 25/200
# 2133/2133 - 10s - loss: 0.5699 - acc: 0.7972 - val_loss: 0.3940 - val_acc: 0.8630 - 10s/epoch - 5ms/step
# Epoch 26/200
# 2133/2133 - 10s - loss: 0.5972 - acc: 0.7957 - val_loss: 0.3611 - val_acc: 0.8753 - 10s/epoch - 5ms/step
# Epoch 27/200
# 2133/2133 - 11s - loss: 0.5707 - acc: 0.7979 - val_loss: 0.3392 - val_acc: 0.8850 - 11s/epoch - 5ms/step
# Epoch 28/200
# 2133/2133 - 10s - loss: 0.5730 - acc: 0.8019 - val_loss: 0.3434 - val_acc: 0.8813 - 10s/epoch - 5ms/step
# Epoch 29/200
# 2133/2133 - 10s - loss: 0.5565 - acc: 0.8026 - val_loss: 0.3594 - val_acc: 0.8815 - 10s/epoch - 5ms/step
# Epoch 30/200
# 2133/2133 - 11s - loss: 0.5534 - acc: 0.8082 - val_loss: 0.3425 - val_acc: 0.8839 - 11s/epoch - 5ms/step
# Epoch 31/200
# 2133/2133 - 10s - loss: 0.5374 - acc: 0.8092 - val_loss: 0.3438 - val_acc: 0.8763 - 10s/epoch - 5ms/step
# Epoch 32/200
# 2133/2133 - 11s - loss: 0.5880 - acc: 0.8035 - val_loss: 0.3476 - val_acc: 0.8767 - 11s/epoch - 5ms/step
# Epoch 33/200
# 2133/2133 - 11s - loss: 0.5543 - acc: 0.8124 - val_loss: 0.3189 - val_acc: 0.8859 - 11s/epoch - 5ms/step
# Epoch 34/200
# 2133/2133 - 10s - loss: 0.5789 - acc: 0.8073 - val_loss: 0.4830 - val_acc: 0.8186 - 10s/epoch - 5ms/step
# Epoch 35/200
# 2133/2133 - 10s - loss: 0.6022 - acc: 0.8104 - val_loss: 0.3196 - val_acc: 0.8808 - 10s/epoch - 5ms/step
# Epoch 36/200
# 2133/2133 - 11s - loss: 0.5402 - acc: 0.8138 - val_loss: 0.2967 - val_acc: 0.8975 - 11s/epoch - 5ms/step
# Epoch 37/200
# 2133/2133 - 10s - loss: 0.5375 - acc: 0.8181 - val_loss: 0.3133 - val_acc: 0.8958 - 10s/epoch - 5ms/step
# Epoch 38/200
# 2133/2133 - 10s - loss: 0.5190 - acc: 0.8167 - val_loss: 0.2883 - val_acc: 0.9009 - 10s/epoch - 5ms/step
# Epoch 39/200
# 2133/2133 - 11s - loss: 0.5275 - acc: 0.8202 - val_loss: 0.2963 - val_acc: 0.9054 - 11s/epoch - 5ms/step
# Epoch 40/200
# 2133/2133 - 10s - loss: 0.4994 - acc: 0.8210 - val_loss: 0.2864 - val_acc: 0.9080 - 10s/epoch - 5ms/step
# Epoch 41/200
# 2133/2133 - 11s - loss: 0.4861 - acc: 0.8236 - val_loss: 0.2676 - val_acc: 0.9091 - 11s/epoch - 5ms/step
# Epoch 42/200
# 2133/2133 - 11s - loss: 0.5170 - acc: 0.8234 - val_loss: 0.2647 - val_acc: 0.9127 - 11s/epoch - 5ms/step
# Epoch 43/200
# 2133/2133 - 10s - loss: 0.4782 - acc: 0.8290 - val_loss: 0.2923 - val_acc: 0.8997 - 10s/epoch - 5ms/step
# Epoch 44/200
# 2133/2133 - 11s - loss: 0.4873 - acc: 0.8262 - val_loss: 0.2582 - val_acc: 0.9164 - 11s/epoch - 5ms/step
# Epoch 45/200
# 2133/2133 - 11s - loss: 0.5446 - acc: 0.8295 - val_loss: 0.3002 - val_acc: 0.9049 - 11s/epoch - 5ms/step
# Epoch 46/200
# 2133/2133 - 10s - loss: 0.5070 - acc: 0.8231 - val_loss: 0.2694 - val_acc: 0.9173 - 10s/epoch - 5ms/step
# Epoch 47/200
# 2133/2133 - 10s - loss: 0.4891 - acc: 0.8326 - val_loss: 0.2548 - val_acc: 0.9135 - 10s/epoch - 5ms/step
# Epoch 48/200
# 2133/2133 - 11s - loss: 0.4835 - acc: 0.8296 - val_loss: 0.2820 - val_acc: 0.9064 - 11s/epoch - 5ms/step
# Epoch 49/200
# 2133/2133 - 10s - loss: 0.4991 - acc: 0.8355 - val_loss: 0.2599 - val_acc: 0.9153 - 10s/epoch - 5ms/step
# Epoch 50/200
# 2133/2133 - 11s - loss: 0.4799 - acc: 0.8360 - val_loss: 0.2931 - val_acc: 0.9022 - 11s/epoch - 5ms/step
# Epoch 51/200
# 2133/2133 - 11s - loss: 0.4990 - acc: 0.8338 - val_loss: 0.2565 - val_acc: 0.9177 - 11s/epoch - 5ms/step
# Epoch 52/200
# 2133/2133 - 10s - loss: 0.5783 - acc: 0.8352 - val_loss: 0.2722 - val_acc: 0.9124 - 10s/epoch - 5ms/step
# Epoch 53/200
# 2133/2133 - 11s - loss: 0.4747 - acc: 0.8372 - val_loss: 0.2464 - val_acc: 0.9182 - 11s/epoch - 5ms/step
# Epoch 54/200
# 2133/2133 - 10s - loss: 0.4839 - acc: 0.8367 - val_loss: 0.2428 - val_acc: 0.9236 - 10s/epoch - 5ms/step
# Epoch 55/200
# 2133/2133 - 11s - loss: 0.4867 - acc: 0.8397 - val_loss: 0.2470 - val_acc: 0.9269 - 11s/epoch - 5ms/step
# Epoch 56/200
# 2133/2133 - 11s - loss: 0.4753 - acc: 0.8360 - val_loss: 0.2533 - val_acc: 0.9204 - 11s/epoch - 5ms/step
# Epoch 57/200
# 2133/2133 - 11s - loss: 0.4885 - acc: 0.8411 - val_loss: 0.2498 - val_acc: 0.9206 - 11s/epoch - 5ms/step
# Epoch 58/200
# 2133/2133 - 11s - loss: 0.4594 - acc: 0.8396 - val_loss: 0.2472 - val_acc: 0.9179 - 11s/epoch - 5ms/step
# Epoch 59/200
# 2133/2133 - 11s - loss: 0.4904 - acc: 0.8413 - val_loss: 0.2301 - val_acc: 0.9255 - 11s/epoch - 5ms/step
# Epoch 60/200
# 2133/2133 - 11s - loss: 0.4851 - acc: 0.8420 - val_loss: 0.2290 - val_acc: 0.9286 - 11s/epoch - 5ms/step
# Epoch 61/200
# 2133/2133 - 11s - loss: 0.4339 - acc: 0.8446 - val_loss: 0.2278 - val_acc: 0.9306 - 11s/epoch - 5ms/step
# Epoch 62/200
# 2133/2133 - 11s - loss: 0.4747 - acc: 0.8468 - val_loss: 0.2368 - val_acc: 0.9268 - 11s/epoch - 5ms/step
# Epoch 63/200
# 2133/2133 - 11s - loss: 0.4639 - acc: 0.8456 - val_loss: 0.2220 - val_acc: 0.9241 - 11s/epoch - 5ms/step
# Epoch 64/200
# 2133/2133 - 11s - loss: 0.4576 - acc: 0.8436 - val_loss: 0.2387 - val_acc: 0.9226 - 11s/epoch - 5ms/step
# Epoch 65/200
# 2133/2133 - 11s - loss: 0.4625 - acc: 0.8459 - val_loss: 0.2261 - val_acc: 0.9263 - 11s/epoch - 5ms/step
# Epoch 66/200
# 2133/2133 - 11s - loss: 0.4287 - acc: 0.8477 - val_loss: 0.2303 - val_acc: 0.9311 - 11s/epoch - 5ms/step
# Epoch 67/200
# 2133/2133 - 11s - loss: 0.4991 - acc: 0.8458 - val_loss: 0.2354 - val_acc: 0.9279 - 11s/epoch - 5ms/step
# Epoch 68/200
# 2133/2133 - 10s - loss: 0.4490 - acc: 0.8480 - val_loss: 0.2204 - val_acc: 0.9277 - 10s/epoch - 5ms/step
# Epoch 69/200
# 2133/2133 - 11s - loss: 0.4836 - acc: 0.8453 - val_loss: 0.2268 - val_acc: 0.9288 - 11s/epoch - 5ms/step
# Epoch 70/200
# 2133/2133 - 10s - loss: 0.4332 - acc: 0.8494 - val_loss: 0.2128 - val_acc: 0.9364 - 10s/epoch - 5ms/step
# Epoch 71/200
# 2133/2133 - 10s - loss: 0.4191 - acc: 0.8516 - val_loss: 0.2224 - val_acc: 0.9290 - 10s/epoch - 5ms/step
# Epoch 72/200
# 2133/2133 - 11s - loss: 0.4361 - acc: 0.8523 - val_loss: 0.2123 - val_acc: 0.9330 - 11s/epoch - 5ms/step
# Epoch 73/200
# 2133/2133 - 10s - loss: 0.4313 - acc: 0.8496 - val_loss: 0.2236 - val_acc: 0.9339 - 10s/epoch - 5ms/step
# Epoch 74/200
# 2133/2133 - 10s - loss: 0.4386 - acc: 0.8451 - val_loss: 0.2266 - val_acc: 0.9297 - 10s/epoch - 5ms/step
# Epoch 75/200
# 2133/2133 - 10s - loss: 0.4251 - acc: 0.8521 - val_loss: 0.2294 - val_acc: 0.9333 - 10s/epoch - 5ms/step
# Epoch 76/200
# 2133/2133 - 10s - loss: 0.4373 - acc: 0.8583 - val_loss: 0.2202 - val_acc: 0.9312 - 10s/epoch - 5ms/step
# Epoch 77/200
# 2133/2133 - 10s - loss: 0.4379 - acc: 0.8535 - val_loss: 0.2044 - val_acc: 0.9359 - 10s/epoch - 5ms/step
# Epoch 78/200
# 2133/2133 - 11s - loss: 0.4381 - acc: 0.8518 - val_loss: 0.2235 - val_acc: 0.9284 - 11s/epoch - 5ms/step
# Epoch 79/200
# 2133/2133 - 10s - loss: 0.4268 - acc: 0.8529 - val_loss: 0.2234 - val_acc: 0.9345 - 10s/epoch - 5ms/step
# Epoch 80/200
# 2133/2133 - 10s - loss: 0.5010 - acc: 0.8546 - val_loss: 0.2129 - val_acc: 0.9325 - 10s/epoch - 5ms/step
# Epoch 81/200
# 2133/2133 - 10s - loss: 0.4561 - acc: 0.8521 - val_loss: 0.2390 - val_acc: 0.9246 - 10s/epoch - 5ms/step
# Epoch 82/200
# 2133/2133 - 10s - loss: 0.4246 - acc: 0.8553 - val_loss: 0.2027 - val_acc: 0.9436 - 10s/epoch - 5ms/step
# Epoch 83/200
# 2133/2133 - 10s - loss: 0.4822 - acc: 0.8558 - val_loss: 0.2298 - val_acc: 0.9196 - 10s/epoch - 5ms/step
# Epoch 84/200
# 2133/2133 - 10s - loss: 0.4647 - acc: 0.8520 - val_loss: 0.2211 - val_acc: 0.9338 - 10s/epoch - 5ms/step
# Epoch 85/200
# 2133/2133 - 10s - loss: 0.4223 - acc: 0.8569 - val_loss: 0.1927 - val_acc: 0.9387 - 10s/epoch - 5ms/step
# Epoch 86/200
# 2133/2133 - 11s - loss: 0.4759 - acc: 0.8601 - val_loss: 0.2127 - val_acc: 0.9337 - 11s/epoch - 5ms/step
# Epoch 87/200
# 2133/2133 - 11s - loss: 0.4770 - acc: 0.8553 - val_loss: 0.1927 - val_acc: 0.9379 - 11s/epoch - 5ms/step
# Epoch 88/200
# 2133/2133 - 10s - loss: 0.4376 - acc: 0.8554 - val_loss: 0.1842 - val_acc: 0.9443 - 10s/epoch - 5ms/step
# Epoch 89/200
# 2133/2133 - 10s - loss: 0.4073 - acc: 0.8613 - val_loss: 0.1945 - val_acc: 0.9391 - 10s/epoch - 5ms/step
# Epoch 90/200
# 2133/2133 - 10s - loss: 0.4083 - acc: 0.8617 - val_loss: 0.1863 - val_acc: 0.9422 - 10s/epoch - 5ms/step
# Epoch 91/200
# 2133/2133 - 11s - loss: 0.4354 - acc: 0.8590 - val_loss: 0.2040 - val_acc: 0.9401 - 11s/epoch - 5ms/step
# Epoch 92/200
# 2133/2133 - 10s - loss: 0.4339 - acc: 0.8591 - val_loss: 0.1973 - val_acc: 0.9412 - 10s/epoch - 5ms/step
# Epoch 93/200
# 2133/2133 - 11s - loss: 0.4631 - acc: 0.8556 - val_loss: 0.1956 - val_acc: 0.9351 - 11s/epoch - 5ms/step
# Epoch 94/200
# 2133/2133 - 11s - loss: 0.4609 - acc: 0.8613 - val_loss: 0.1957 - val_acc: 0.9451 - 11s/epoch - 5ms/step
# Epoch 95/200
# 2133/2133 - 10s - loss: 0.3893 - acc: 0.8607 - val_loss: 0.2026 - val_acc: 0.9393 - 10s/epoch - 5ms/step
# Epoch 96/200
# 2133/2133 - 11s - loss: 0.3819 - acc: 0.8667 - val_loss: 0.1966 - val_acc: 0.9434 - 11s/epoch - 5ms/step
# Epoch 97/200
# 2133/2133 - 10s - loss: 0.4073 - acc: 0.8641 - val_loss: 0.2008 - val_acc: 0.9361 - 10s/epoch - 5ms/step
# Epoch 98/200
# 2133/2133 - 10s - loss: 0.4336 - acc: 0.8617 - val_loss: 0.2132 - val_acc: 0.9338 - 10s/epoch - 5ms/step
# Epoch 99/200
# 2133/2133 - 11s - loss: 0.4420 - acc: 0.8663 - val_loss: 0.1846 - val_acc: 0.9373 - 11s/epoch - 5ms/step
# Epoch 100/200
# 2133/2133 - 10s - loss: 0.4797 - acc: 0.8602 - val_loss: 0.1950 - val_acc: 0.9428 - 10s/epoch - 5ms/step
# Epoch 101/200
# 2133/2133 - 10s - loss: 0.4310 - acc: 0.8590 - val_loss: 0.1907 - val_acc: 0.9451 - 10s/epoch - 5ms/step
# Epoch 102/200
# 2133/2133 - 11s - loss: 0.4655 - acc: 0.8599 - val_loss: 0.2044 - val_acc: 0.9366 - 11s/epoch - 5ms/step
# Epoch 103/200
# 2133/2133 - 10s - loss: 0.4573 - acc: 0.8588 - val_loss: 0.2098 - val_acc: 0.9371 - 10s/epoch - 5ms/step
# Epoch 104/200
# 2133/2133 - 10s - loss: 0.4112 - acc: 0.8624 - val_loss: 0.2042 - val_acc: 0.9286 - 10s/epoch - 5ms/step
# Epoch 105/200
# 2133/2133 - 11s - loss: 0.3891 - acc: 0.8638 - val_loss: 0.1848 - val_acc: 0.9405 - 11s/epoch - 5ms/step
# Epoch 106/200
# 2133/2133 - 10s - loss: 0.4081 - acc: 0.8680 - val_loss: 0.2124 - val_acc: 0.9310 - 10s/epoch - 5ms/step
# Epoch 107/200
# 2133/2133 - 10s - loss: 0.3799 - acc: 0.8668 - val_loss: 0.1775 - val_acc: 0.9407 - 10s/epoch - 5ms/step
# Epoch 108/200
# 2133/2133 - 10s - loss: 0.4297 - acc: 0.8690 - val_loss: 0.1938 - val_acc: 0.9476 - 10s/epoch - 5ms/step
# Epoch 109/200
# 2133/2133 - 10s - loss: 0.4090 - acc: 0.8598 - val_loss: 0.1794 - val_acc: 0.9425 - 10s/epoch - 5ms/step
# Epoch 110/200
# 2133/2133 - 10s - loss: 0.3794 - acc: 0.8701 - val_loss: 0.1760 - val_acc: 0.9495 - 10s/epoch - 5ms/step
# Epoch 111/200
# 2133/2133 - 11s - loss: 0.3841 - acc: 0.8727 - val_loss: 0.1830 - val_acc: 0.9476 - 11s/epoch - 5ms/step
# Epoch 112/200
# 2133/2133 - 10s - loss: 0.4163 - acc: 0.8680 - val_loss: 0.1824 - val_acc: 0.9438 - 10s/epoch - 5ms/step
# Epoch 113/200
# 2133/2133 - 10s - loss: 0.4415 - acc: 0.8645 - val_loss: 0.1839 - val_acc: 0.9467 - 10s/epoch - 5ms/step
# Epoch 114/200
# 2133/2133 - 11s - loss: 0.4261 - acc: 0.8700 - val_loss: 0.1758 - val_acc: 0.9523 - 11s/epoch - 5ms/step
# Epoch 115/200
# 2133/2133 - 10s - loss: 0.4719 - acc: 0.8700 - val_loss: 0.1793 - val_acc: 0.9465 - 10s/epoch - 5ms/step
# Epoch 116/200
# 2133/2133 - 10s - loss: 0.4510 - acc: 0.8609 - val_loss: 0.1636 - val_acc: 0.9507 - 10s/epoch - 5ms/step
# Epoch 117/200
# 2133/2133 - 11s - loss: 0.4378 - acc: 0.8697 - val_loss: 0.1761 - val_acc: 0.9445 - 11s/epoch - 5ms/step
# Epoch 118/200
# 2133/2133 - 10s - loss: 0.3997 - acc: 0.8696 - val_loss: 0.1620 - val_acc: 0.9502 - 10s/epoch - 5ms/step
# Epoch 119/200
# 2133/2133 - 10s - loss: 0.4139 - acc: 0.8716 - val_loss: 0.1756 - val_acc: 0.9512 - 10s/epoch - 5ms/step
# Epoch 120/200
# 2133/2133 - 11s - loss: 0.3881 - acc: 0.8705 - val_loss: 0.1615 - val_acc: 0.9552 - 11s/epoch - 5ms/step
# Epoch 121/200
# 2133/2133 - 11s - loss: 0.3596 - acc: 0.8720 - val_loss: 0.1808 - val_acc: 0.9458 - 11s/epoch - 5ms/step
# Epoch 122/200
# 2133/2133 - 10s - loss: 0.4401 - acc: 0.8738 - val_loss: 0.1911 - val_acc: 0.9429 - 10s/epoch - 5ms/step
# Epoch 123/200
# 2133/2133 - 10s - loss: 0.3588 - acc: 0.8758 - val_loss: 0.1721 - val_acc: 0.9528 - 10s/epoch - 5ms/step
# Epoch 124/200
# 2133/2133 - 10s - loss: 0.5333 - acc: 0.8693 - val_loss: 0.1814 - val_acc: 0.9354 - 10s/epoch - 5ms/step
# Epoch 125/200
# 2133/2133 - 10s - loss: 0.4767 - acc: 0.8651 - val_loss: 0.1809 - val_acc: 0.9458 - 10s/epoch - 5ms/step
# Epoch 126/200
# 2133/2133 - 11s - loss: 0.3850 - acc: 0.8713 - val_loss: 0.1665 - val_acc: 0.9528 - 11s/epoch - 5ms/step
# Epoch 127/200
# 2133/2133 - 10s - loss: 0.4127 - acc: 0.8713 - val_loss: 0.2005 - val_acc: 0.9435 - 10s/epoch - 5ms/step
# Epoch 128/200
# 2133/2133 - 10s - loss: 0.4099 - acc: 0.8665 - val_loss: 0.1679 - val_acc: 0.9441 - 10s/epoch - 5ms/step
# Epoch 129/200
# 2133/2133 - 11s - loss: 0.3815 - acc: 0.8731 - val_loss: 0.1688 - val_acc: 0.9438 - 11s/epoch - 5ms/step
# Epoch 130/200
# 2133/2133 - 11s - loss: 0.3795 - acc: 0.8717 - val_loss: 0.1701 - val_acc: 0.9546 - 11s/epoch - 5ms/step
# Epoch 131/200
# 2133/2133 - 10s - loss: 0.3987 - acc: 0.8688 - val_loss: 0.1635 - val_acc: 0.9486 - 10s/epoch - 5ms/step
# Epoch 132/200
# 2133/2133 - 11s - loss: 0.4289 - acc: 0.8727 - val_loss: 0.1837 - val_acc: 0.9435 - 11s/epoch - 5ms/step
# Epoch 133/200
# 2133/2133 - 10s - loss: 0.3843 - acc: 0.8731 - val_loss: 0.1654 - val_acc: 0.9524 - 10s/epoch - 5ms/step
# Epoch 134/200
# 2133/2133 - 10s - loss: 0.4067 - acc: 0.8782 - val_loss: 0.1590 - val_acc: 0.9539 - 10s/epoch - 5ms/step
# Epoch 135/200
# 2133/2133 - 11s - loss: 0.4309 - acc: 0.8730 - val_loss: 0.1725 - val_acc: 0.9451 - 11s/epoch - 5ms/step
# Epoch 136/200
# 2133/2133 - 11s - loss: 0.4398 - acc: 0.8647 - val_loss: 0.1600 - val_acc: 0.9532 - 11s/epoch - 5ms/step
# Epoch 137/200
# 2133/2133 - 10s - loss: 0.3831 - acc: 0.8710 - val_loss: 0.1640 - val_acc: 0.9489 - 10s/epoch - 5ms/step
# Epoch 138/200
# 2133/2133 - 11s - loss: 0.3627 - acc: 0.8728 - val_loss: 0.1543 - val_acc: 0.9504 - 11s/epoch - 5ms/step
# Epoch 139/200
# 2133/2133 - 10s - loss: 0.4151 - acc: 0.8770 - val_loss: 0.1681 - val_acc: 0.9516 - 10s/epoch - 5ms/step
# Epoch 140/200
# 2133/2133 - 10s - loss: 0.4106 - acc: 0.8743 - val_loss: 0.1604 - val_acc: 0.9539 - 10s/epoch - 5ms/step
# Epoch 141/200
# 2133/2133 - 11s - loss: 0.4916 - acc: 0.8745 - val_loss: 0.1662 - val_acc: 0.9526 - 11s/epoch - 5ms/step
# Epoch 142/200
# 2133/2133 - 10s - loss: 0.5182 - acc: 0.8705 - val_loss: 0.1740 - val_acc: 0.9523 - 10s/epoch - 5ms/step
# Epoch 143/200
# 2133/2133 - 11s - loss: 0.3833 - acc: 0.8736 - val_loss: 0.1576 - val_acc: 0.9502 - 11s/epoch - 5ms/step
# Epoch 144/200
# 2133/2133 - 11s - loss: 0.4186 - acc: 0.8772 - val_loss: 0.1679 - val_acc: 0.9450 - 11s/epoch - 5ms/step
# Epoch 145/200
# 2133/2133 - 10s - loss: 0.3752 - acc: 0.8760 - val_loss: 0.1624 - val_acc: 0.9513 - 10s/epoch - 5ms/step
# Epoch 146/200
# 2133/2133 - 10s - loss: 0.4251 - acc: 0.8770 - val_loss: 0.1686 - val_acc: 0.9452 - 10s/epoch - 5ms/step
# Epoch 147/200
# 2133/2133 - 11s - loss: 0.3944 - acc: 0.8771 - val_loss: 0.1577 - val_acc: 0.9561 - 11s/epoch - 5ms/step
# Epoch 148/200
# 2133/2133 - 11s - loss: 0.3678 - acc: 0.8732 - val_loss: 0.1570 - val_acc: 0.9557 - 11s/epoch - 5ms/step
# Epoch 149/200
# 2133/2133 - 11s - loss: 0.4101 - acc: 0.8799 - val_loss: 0.1711 - val_acc: 0.9452 - 11s/epoch - 5ms/step
# Epoch 150/200
# 2133/2133 - 11s - loss: 0.3947 - acc: 0.8763 - val_loss: 0.1450 - val_acc: 0.9539 - 11s/epoch - 5ms/step
# Epoch 151/200
# 2133/2133 - 11s - loss: 0.4076 - acc: 0.8769 - val_loss: 0.1462 - val_acc: 0.9589 - 11s/epoch - 5ms/step
# Epoch 152/200
# 2133/2133 - 10s - loss: 0.4808 - acc: 0.8753 - val_loss: 0.1491 - val_acc: 0.9573 - 10s/epoch - 5ms/step
# Epoch 153/200
# 2133/2133 - 11s - loss: 0.3877 - acc: 0.8789 - val_loss: 0.1674 - val_acc: 0.9510 - 11s/epoch - 5ms/step
# Epoch 154/200
# 2133/2133 - 10s - loss: 0.3694 - acc: 0.8774 - val_loss: 0.1636 - val_acc: 0.9497 - 10s/epoch - 5ms/step
# Epoch 155/200
# 2133/2133 - 11s - loss: 0.3854 - acc: 0.8826 - val_loss: 0.1773 - val_acc: 0.9501 - 11s/epoch - 5ms/step
# Epoch 156/200
# 2133/2133 - 11s - loss: 0.3810 - acc: 0.8780 - val_loss: 0.1712 - val_acc: 0.9541 - 11s/epoch - 5ms/step
# Epoch 157/200
# 2133/2133 - 11s - loss: 0.4166 - acc: 0.8780 - val_loss: 0.1419 - val_acc: 0.9595 - 11s/epoch - 5ms/step
# Epoch 158/200
# 2133/2133 - 11s - loss: 0.4110 - acc: 0.8828 - val_loss: 0.1603 - val_acc: 0.9569 - 11s/epoch - 5ms/step
# Epoch 159/200
# 2133/2133 - 11s - loss: 0.3811 - acc: 0.8762 - val_loss: 0.1641 - val_acc: 0.9493 - 11s/epoch - 5ms/step
# Epoch 160/200
# 2133/2133 - 10s - loss: 0.4089 - acc: 0.8775 - val_loss: 0.1530 - val_acc: 0.9543 - 10s/epoch - 5ms/step
# Epoch 161/200
# 2133/2133 - 10s - loss: 0.4549 - acc: 0.8778 - val_loss: 0.1539 - val_acc: 0.9544 - 10s/epoch - 5ms/step
# Epoch 162/200
# 2133/2133 - 11s - loss: 0.3885 - acc: 0.8766 - val_loss: 0.1562 - val_acc: 0.9611 - 11s/epoch - 5ms/step
# Epoch 163/200
# 2133/2133 - 11s - loss: 0.4296 - acc: 0.8795 - val_loss: 0.1579 - val_acc: 0.9450 - 11s/epoch - 5ms/step
# Epoch 164/200
# 2133/2133 - 11s - loss: 0.4050 - acc: 0.8755 - val_loss: 0.1440 - val_acc: 0.9545 - 11s/epoch - 5ms/step
# Epoch 165/200
# 2133/2133 - 11s - loss: 0.4014 - acc: 0.8801 - val_loss: 0.1616 - val_acc: 0.9532 - 11s/epoch - 5ms/step
# Epoch 166/200
# 2133/2133 - 11s - loss: 0.4571 - acc: 0.8762 - val_loss: 0.1629 - val_acc: 0.9481 - 11s/epoch - 5ms/step
# Epoch 167/200
# 2133/2133 - 11s - loss: 0.3850 - acc: 0.8745 - val_loss: 0.1573 - val_acc: 0.9546 - 11s/epoch - 5ms/step
# Epoch 168/200
# 2133/2133 - 11s - loss: 0.3635 - acc: 0.8802 - val_loss: 0.1595 - val_acc: 0.9535 - 11s/epoch - 5ms/step
# Epoch 169/200
# 2133/2133 - 11s - loss: 0.3560 - acc: 0.8819 - val_loss: 0.1712 - val_acc: 0.9495 - 11s/epoch - 5ms/step
# Epoch 170/200
# 2133/2133 - 11s - loss: 0.4672 - acc: 0.8782 - val_loss: 0.1581 - val_acc: 0.9540 - 11s/epoch - 5ms/step
# Epoch 171/200
# 2133/2133 - 11s - loss: 0.4049 - acc: 0.8728 - val_loss: 0.1745 - val_acc: 0.9420 - 11s/epoch - 5ms/step
# Epoch 172/200
# 2133/2133 - 11s - loss: 0.4178 - acc: 0.8773 - val_loss: 0.1536 - val_acc: 0.9562 - 11s/epoch - 5ms/step
# Epoch 173/200
# 2133/2133 - 11s - loss: 0.3894 - acc: 0.8829 - val_loss: 0.1551 - val_acc: 0.9502 - 11s/epoch - 5ms/step
# Epoch 174/200
# 2133/2133 - 11s - loss: 0.3665 - acc: 0.8836 - val_loss: 0.1525 - val_acc: 0.9496 - 11s/epoch - 5ms/step
# Epoch 175/200
# 2133/2133 - 11s - loss: 0.3901 - acc: 0.8773 - val_loss: 0.1439 - val_acc: 0.9553 - 11s/epoch - 5ms/step
# Epoch 176/200
# 2133/2133 - 11s - loss: 0.4872 - acc: 0.8810 - val_loss: 0.1582 - val_acc: 0.9439 - 11s/epoch - 5ms/step
# Epoch 177/200
# 2133/2133 - 11s - loss: 0.3835 - acc: 0.8809 - val_loss: 0.1498 - val_acc: 0.9602 - 11s/epoch - 5ms/step
# Epoch 178/200
# 2133/2133 - 11s - loss: 0.4795 - acc: 0.8794 - val_loss: 0.1454 - val_acc: 0.9580 - 11s/epoch - 5ms/step
# Epoch 179/200
# 2133/2133 - 11s - loss: 0.4794 - acc: 0.8715 - val_loss: 0.1530 - val_acc: 0.9523 - 11s/epoch - 5ms/step
# Epoch 180/200
# 2133/2133 - 11s - loss: 0.4054 - acc: 0.8773 - val_loss: 0.1524 - val_acc: 0.9525 - 11s/epoch - 5ms/step
# Epoch 181/200
# 2133/2133 - 11s - loss: 0.3659 - acc: 0.8872 - val_loss: 0.1628 - val_acc: 0.9503 - 11s/epoch - 5ms/step
# Epoch 182/200
# 2133/2133 - 11s - loss: 0.4547 - acc: 0.8764 - val_loss: 0.1490 - val_acc: 0.9580 - 11s/epoch - 5ms/step
# Epoch 183/200
# 2133/2133 - 11s - loss: 0.3961 - acc: 0.8779 - val_loss: 0.1530 - val_acc: 0.9504 - 11s/epoch - 5ms/step
# Epoch 184/200
# 2133/2133 - 11s - loss: 0.5613 - acc: 0.8813 - val_loss: 0.1559 - val_acc: 0.9553 - 11s/epoch - 5ms/step
# Epoch 185/200
# 2133/2133 - 11s - loss: 0.4393 - acc: 0.8751 - val_loss: 0.1499 - val_acc: 0.9605 - 11s/epoch - 5ms/step
# Epoch 186/200
# 2133/2133 - 11s - loss: 0.4070 - acc: 0.8752 - val_loss: 0.1552 - val_acc: 0.9531 - 11s/epoch - 5ms/step
# Epoch 187/200
# 2133/2133 - 11s - loss: 0.4495 - acc: 0.8840 - val_loss: 0.1589 - val_acc: 0.9593 - 11s/epoch - 5ms/step
# Epoch 188/200
# 2133/2133 - 11s - loss: 0.4310 - acc: 0.8748 - val_loss: 0.1490 - val_acc: 0.9550 - 11s/epoch - 5ms/step
# Epoch 189/200
# 2133/2133 - 11s - loss: 0.4475 - acc: 0.8806 - val_loss: 0.1560 - val_acc: 0.9486 - 11s/epoch - 5ms/step
# Epoch 190/200
# 2133/2133 - 10s - loss: 0.5247 - acc: 0.8746 - val_loss: 0.1743 - val_acc: 0.9429 - 10s/epoch - 5ms/step
# Epoch 191/200
# 2133/2133 - 11s - loss: 0.3585 - acc: 0.8766 - val_loss: 0.1496 - val_acc: 0.9599 - 11s/epoch - 5ms/step
# Epoch 192/200
# 2133/2133 - 11s - loss: 0.3979 - acc: 0.8897 - val_loss: 0.1412 - val_acc: 0.9606 - 11s/epoch - 5ms/step
# Epoch 193/200
# 2133/2133 - 10s - loss: 0.4130 - acc: 0.8826 - val_loss: 0.1459 - val_acc: 0.9571 - 10s/epoch - 5ms/step
# Epoch 194/200
# 2133/2133 - 11s - loss: 0.4058 - acc: 0.8843 - val_loss: 0.1339 - val_acc: 0.9600 - 11s/epoch - 5ms/step
# Epoch 195/200
# 2133/2133 - 10s - loss: 0.5366 - acc: 0.8735 - val_loss: 0.1748 - val_acc: 0.9410 - 10s/epoch - 5ms/step
# Epoch 196/200
# 2133/2133 - 11s - loss: 0.4597 - acc: 0.8749 - val_loss: 0.1507 - val_acc: 0.9531 - 11s/epoch - 5ms/step
# Epoch 197/200
# 2133/2133 - 11s - loss: 0.3517 - acc: 0.8860 - val_loss: 0.1462 - val_acc: 0.9594 - 11s/epoch - 5ms/step
# Epoch 198/200
# 2133/2133 - 11s - loss: 0.3959 - acc: 0.8868 - val_loss: 0.1475 - val_acc: 0.9535 - 11s/epoch - 5ms/step
# Epoch 199/200
# 2133/2133 - 10s - loss: 0.3437 - acc: 0.8855 - val_loss: 0.1450 - val_acc: 0.9589 - 10s/epoch - 5ms/step
# Epoch 200/200
# 2133/2133 - 11s - loss: 0.4091 - acc: 0.8799 - val_loss: 0.1599 - val_acc: 0.9588 - 11s/epoch - 5ms/step
# 356/356 [==============================] - 1s 3ms/step - loss: 0.1599 - acc: 0.9588
# Test accuracy: 0.9587692022323608

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Prediction on test data
y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
y_pred_classes = np.argmax(y_pred, axis = 1) 
# Convert test data to one hot vectors
y_true = np.argmax(y_test, axis = 1)
# Out:
# 356/356 [==============================] - 1s 2ms/step

# %%
#Print confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %%
#PLot fractional incorrect misclassifications
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(7), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
# Out:
# Text(0, 0.5, 'Fraction of incorrect predictions')

# %%
model.save('final_model.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
